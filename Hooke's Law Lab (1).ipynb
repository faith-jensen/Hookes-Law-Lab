# %% [markdown]
# # Method 2 are the first plots-Method 1 are the last two plots

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([50, 100, 150, 200, 250, 300])/1000
T = np.array([3.99, 5.71, 7.05, 8.19, 9.15, 9.96])/10
errT = np.array([.029526, .042254, .05217, .060606, .06771, .073704])

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(m1,T**2,errT,'Method 2 Spring 1','m(kg)','T**2','N/m')
# Out:
# Slope = 3.33 N/m
# Error in slope = 0.24 N/m
# Goodness of fit = 0.08

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([150, 175, 200, 225, 250, 275])/1000
T = np.array([1.406, 1.502, 1.619, 1.715, 1.809, 1.911])
errT = np.array([.104044, .111148, .0859806, .12691, .133866, .141414])

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(m1,T**2,errT,'Method 2 Spring 2','m(kg)','T**2','N/m')
# Out:
# Slope = 13.49 N/m
# Error in slope = 1.17 N/m
# Goodness of fit = 0.22

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([50, 100, 150, 200, 250, 300])/1000
x1 = np.array([17, 34, 50, 66, 82, 98])/100
errm = np.array([1, 1, 1, 1, 1, 1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'Method 1 Spring 1','x(m)','F(N)','N/m')
# Out:
# Slope = 3.04 N/m
# Error in slope = 0.01 N/m
# Goodness of fit = 4.57

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([50, 100, 150, 200, 250, 300])/1000
x1 = np.array([5, 9, 13, 17, 21, 25])/100
errm = np.array([1, 1, 1, 1, 1, 1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'Method 1 Spring 2','x(m)','F(N)','N/m')
# Out:
# Slope = 12.25 N/m
# Error in slope = 0.06 N/m
# Goodness of fit = 0.00
